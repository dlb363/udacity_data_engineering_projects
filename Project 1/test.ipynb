# %%
import sql

# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb

# %%
# %sql SELECT * FROM d LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# (psycopg2.errors.UndefinedTable) relation "d" does not exist
# LINE 1: SELECT * FROM d LIMIT 5;
#                       ^
#
# [SQL: SELECT * FROM d LIMIT 5;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %sql SELECT * from artists
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 69 rows affected.
# [('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', '', nan, nan),
#  ('ARXR32B1187FB57099', 'Gob', '', nan, nan),
#  ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', nan, nan),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.21962, -80.01955),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35.14968, -90.04892),
#  ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan),
#  ('ARKRRTF1187B9984DA', 'Sonora Santanera', '', nan, nan),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', nan, nan),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', nan, nan),
#  ('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', nan, nan),
#  ('ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', 40.73197, -74.17418),
#  ('ARB29H41187B98F0EF', 'Terry Callier', 'Chicago', 41.88415, -87.63241),
#  ('AR0RCMP1187FB3F427', 'Billie Jo Spears', 'Beaumont, TX', 30.08615, -94.10158),
#  ('AR47JEX1187B995D81', 'SUE THOMPSON', 'Nevada, MO', 37.83721, -94.35868),
#  ('AREBBGV1187FB523D2', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 'Houston, TX', nan, nan),
#  ('ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', 40.82624, -74.47995),
#  ('ARAJPHH1187FB5566A', 'The Shangri-Las', 'Queens, NY', 40.7038, -73.83168),
#  ('ARGIWFO1187B9B55B7', 'Five Bolt Main', '', nan, nan),
#  ('ARDNS031187B9924F0', 'Tim Wilson', 'Georgia', 32.67828, -83.22295),
#  ('ARGUVEV1187B98BA17', 'Sierra Maestra', '', nan, nan),
#  ('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', 49.80388, 15.47491),
#  ('AR1Y2PT1187FB5B9CE', 'John Wesley', 'Brandon', 27.94017, -82.32547),
#  ('AROUOZZ1187B9ABE51', 'Willie Bobo', 'New York, NY [Spanish Harlem]', 40.79195, -73.94512),
#  ('ARL7K851187B99ACD2', 'Andy Andy', '', nan, nan),
#  ('ARNPAGP1241B9C7FD4', 'lextrical', '', nan, nan),
#  ('ARQGYP71187FB44566', 'Jimmy Wakely', 'Mineola, AR', 34.31109, -94.02978),
#  ('ARIG6O41187B988BDD', 'Richard Souther', 'United States', 37.16793, -95.84502),
#  ('ARHHO3O1187B989413', 'Bob Azzam', '', nan, nan),
#  ('ARC43071187B990240', 'Wayne Watson', 'Wisner, LA', nan, nan),
#  ('ARI3BMM1187FB4255E', 'Alice Stuart', 'Washington', 38.8991, -77.029),
#  ('ARIK43K1187B9AE54C', 'Lionel Richie', 'Beverly Hills, CA', nan, nan),
#  ('ARD842G1187B997376', 'Blue Rodeo', 'Toronto, Ontario, Canada', 43.64856, -79.38533),
#  ('AR1ZHYZ1187FB3C717', 'Faiz Ali Faiz', '', nan, nan),
#  ('ARYKCQI1187FB3B18F', 'Tesla', '', nan, nan),
#  ('ARMBR4Y1187B9990EB', 'David Martin', 'California - SF', 37.77916, -122.42005),
#  ('AR9AWNF1187B9AB0B4', 'Kenny G featuring Daryl Hall', 'Seattle, Washington USA', nan, nan),
#  ('ARQ9BO41187FB5CF1F', 'John Davis', 'Pennsylvania', 40.99471, -77.60454),
#  ('AR3JMC51187B9AE49D', 'Backstreet Boys', 'Orlando, FL', 28.53823, -81.37739),
#  ('AREDBBQ1187B98AFF5', 'Eddie Calvert', '', nan, nan),
#  ('ARPBNLO1187FB3D52F', 'Tiny Tim', 'New York, NY', 40.71455, -74.00712),
#  ('ARKULSX1187FB45F84', 'Trafik', 'Utah', 39.49974, -111.54732),
#  ('AROGWRA122988FEE45', 'Christos Dantis', '', nan, nan),
#  ('ARI2JSK1187FB496EF', 'Nick Ingman;Gavyn Wright', 'London, England', 51.50632, -0.12714),
#  ('AR7ZKHQ1187B98DD73', 'Glad', '', nan, nan),
#  ('ARLTWXK1187FB5A3F8', 'King Curtis', 'Fort Worth, TX', 32.74863, -97.32925),
#  ('ARULZCI1241B9C8611', 'Luna Orbit Project', '', nan, nan),
#  ('ARPFHN61187FB575F6', 'Lupe Fiasco', 'Chicago, IL', 41.88415, -87.63241),
#  ('ARJIE2Y1187B994AB7', 'Line Renaud', '', nan, nan),
#  ('AR0IAWL1187B9A96D0', 'Danilo Perez', 'Panama', 8.4177, -80.11278),
#  ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', nan, nan),
#  ('AR8IEZO1187B99055E', 'Marc Shaiman', '', nan, nan),
#  ('ARWB3G61187FB49404', 'Steve Morse', 'Hamilton, Ohio', nan, nan),
#  ('AR051KA1187B98B2FF', 'Wilks', '', nan, nan),
#  ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', -13.442, -41.9952),
#  ('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', 40.79086, -73.96644),
#  ('AR558FS1187FB45658', '40 Grit', '', nan, nan),
#  ('AR36F9J1187FB406F1', 'Bombay Rockers', 'Denmark', 56.27609, 9.51695),
#  ('AR7SMBG1187B9B9066', 'Los Manolos', '', nan, nan),
#  ('ARDR4AC1187FB371A1', 'Montserrat Caballé;Placido Domingo;Vicente Sardinero;Judith Blegen;Sherrill Milnes;Georg Solti', '', nan, nan),
#  ('ARBGXIG122988F409D', 'Steel Rain', 'California - SF', 37.77916, -122.42005),
#  ('AREDL271187FB40F44', 'Soul Mekanik', '', nan, nan),
#  ('ARP6N5A1187B99D1A3', 'Mitch Ryder', 'Hamtramck, MI', nan, nan),
#  ('ARGSAFR1269FB35070', 'Blingtones', '', nan, nan),
#  ('ARAGB2O1187FB3A161', 'Pucho & His Latin Soul Brothers', '', nan, nan),
#  ('AR62SOJ1187FB47BB5', 'Chase & Status', '', nan, nan),
#  ('ARBEBBY1187B9B43DB', 'Tom Petty', 'Gainesville, FL', nan, nan),
#  ('ARNNKDK1187B98BBD5', 'Jinx', 'Zagreb Croatia', 45.80726, 15.967600000000001),
#  ('ARGCY1Y1187B9A4FA5', 'Gloriana', 'Nashville, TN.', 36.16778, -86.77836)]

# %%
# %sql SELECT * from users
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 96 rows affected.
# [(69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (92, 'Ryann', 'Smith', 'F', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free'),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'free'),
#  (96, 'Cierra', 'Finley', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (44, 'Aleena', 'Kirby', 'F', 'paid'),
#  (67, 'Colm', 'Santana', 'M', 'free'),
#  (62, 'Connar', 'Moreno', 'M', 'free'),
#  (14, 'Theodore', 'Harris', 'M', 'free'),
#  (16, 'Rylan', 'George', 'M', 'free'),
#  (80, 'Tegan', 'Levine', 'F', 'paid'),
#  (35, 'Molly', 'Taylor', 'F', 'free'),
#  (66, 'Kevin', 'Arellano', 'M', 'free'),
#  (63, 'Ayla', 'Johnson', 'F', 'free'),
#  (58, 'Emily', 'Benson', 'F', 'paid'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (53, 'Celeste', 'Williams', 'F', 'free'),
#  (56, 'Cienna', 'Freeman', 'F', 'free'),
#  (94, 'Noah', 'Chavez', 'M', 'free'),
#  (98, 'Jordyn', 'Powell', 'F', 'free'),
#  (90, 'Andrea', 'Butler', 'F', 'free'),
#  (86, 'Aiden', 'Hess', 'M', 'free'),
#  (40, 'Tucker', 'Garrison', 'M', 'free'),
#  (30, 'Avery', 'Watkins', 'F', 'paid'),
#  (60, 'Devin', 'Larson', 'M', 'free'),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (17, 'Makinley', 'Jones', 'F', 'free'),
#  (85, 'Kinsley', 'Young', 'F', 'paid'),
#  (47, 'Kimber', 'Norris', 'F', 'free'),
#  (83, 'Stefany', 'White', 'F', 'free'),
#  (79, 'James', 'Martin', 'M', 'free'),
#  (29, 'Jacqueline', 'Lynch', 'F', 'paid'),
#  (78, 'Chloe', 'Roth', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (77, 'Magdalene', 'Herman', 'F', 'free'),
#  (99, 'Ann', 'Banks', 'F', 'free'),
#  (43, 'Jahiem', 'Miles', 'M', 'free'),
#  (25, 'Jayden', 'Graves', 'M', 'paid'),
#  (51, 'Maia', 'Burke', 'F', 'free'),
#  (37, 'Jordan', 'Hicks', 'F', 'free'),
#  (28, 'Brantley', 'West', 'M', 'free'),
#  (74, 'Braden', 'Parker', 'M', 'free'),
#  (100, 'Adler', 'Barrera', 'M', 'free'),
#  (33, 'Bronson', 'Harris', 'M', 'free'),
#  (73, 'Jacob', 'Klein', 'M', 'paid'),
#  (101, 'Jayden', 'Fox', 'M', 'free'),
#  (95, 'Sara', 'Johnson', 'F', 'paid'),
#  (9, 'Wyatt', 'Scott', 'M', 'free'),
#  (4, 'Alivia', 'Terrell', 'F', 'free'),
#  (59, 'Lily', 'Cooper', 'F', 'free'),
#  (15, 'Lily', 'Koch', 'F', 'paid'),
#  (97, 'Kate', 'Harrell', 'F', 'paid'),
#  (34, 'Evelin', 'Ayala', 'F', 'free'),
#  (89, 'Kynnedi', 'Sanchez', 'F', 'free'),
#  (20, 'Aiden', 'Ramirez', 'M', 'paid'),
#  (11, 'Christian', 'Porter', 'F', 'free'),
#  (48, 'Marina', 'Sutton', 'F', 'free'),
#  (72, 'Hayden', 'Brock', 'F', 'paid'),
#  (81, 'Sienna', 'Colon', 'F', 'free'),
#  (36, 'Matthew', 'Jones', 'M', 'free'),
#  (7, 'Adelyn', 'Jordan', 'F', 'free'),
#  (27, 'Carlos', 'Carter', 'M', 'free'),
#  (42, 'Harper', 'Barrett', 'M', 'paid'),
#  (54, 'Kaleb', 'Cook', 'M', 'free'),
#  (52, 'Theodore', 'Smith', 'M', 'free'),
#  (76, 'Jayden', 'Duffy', 'F', 'free'),
#  (2, 'Jizelle', 'Benjamin', 'F', 'free'),
#  (70, 'Jaleah', 'Hayes', 'F', 'paid'),
#  (71, 'Ayleen', 'Wise', 'F', 'free'),
#  (3, 'Isaac', 'Valdez', 'M', 'free'),
#  (91, 'Jayden', 'Bell', 'M', 'free'),
#  (57, 'Katherine', 'Gay', 'F', 'free'),
#  (12, 'Austin', 'Rosales', 'M', 'free'),
#  (5, 'Elijah', 'Davis', 'M', 'free'),
#  (23, 'Morris', 'Gilmore', 'M', 'free'),
#  (84, 'Shakira', 'Hunt', 'F', 'free'),
#  (82, 'Avery', 'Martinez', 'F', 'paid'),
#  (39, 'Walter', 'Frye', 'M', 'free'),
#  (55, 'Martin', 'Johnson', 'M', 'free'),
#  (22, 'Sean', 'Wilson', 'F', 'free'),
#  (41, 'Brayden', 'Clark', 'M', 'free'),
#  (18, 'Jacob', 'Rogers', 'M', 'free'),
#  (64, 'Hannah', 'Calhoun', 'F', 'free'),
#  (68, 'Jordan', 'Rodriguez', 'F', 'free'),
#  (13, 'Ava', 'Robinson', 'F', 'free'),
#  (38, 'Gianna', 'Jones', 'F', 'free'),
#  (45, 'Dominick', 'Norris', 'M', 'free'),
#  (65, 'Amiya', 'Davidson', 'F', 'paid'),
#  (19, 'Zachary', 'Thomas', 'M', 'free'),
#  (87, 'Dustin', 'Lee', 'M', 'free')]

# %%
# %sql SELECT * from songs
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 270),
#  ('SOFSOCN12A8C143F5D', 'Face the Ashes', 'ARXR32B1187FB57099', 2007, 210),
#  ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, 190),
#  ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, 219),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, 148),
#  ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 219),
#  ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', 0, 177),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', 0, 268),
#  ('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, 115),
#  ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, 156),
#  ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 'ARB29H41187B98F0EF', 1972, 343),
#  ('SOGXHEG12AB018653E', 'It Makes No Difference Now', 'AR0RCMP1187FB3F427', 1992, 133),
#  ('SOBLGCN12AB0183212', 'James (Hold The Ladder Steady)', 'AR47JEX1187B995D81', 1985, 125),
#  ('SOZQDIU12A58A7BCF6', 'Superconfidential', 'ARNTLGG11E2835DDB9', 0, 338),
#  ('SOOLYAZ12A6701F4A6', 'Laws Patrolling (Album Version)', 'AREBBGV1187FB523D2', 0, 174),
#  ('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, 208),
#  ('SOYTPEP12AB0180E7B', 'Twist and Shout', 'ARAJPHH1187FB5566A', 1964, 165),
#  ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 'ARGIWFO1187B9B55B7', 0, 225),
#  ('SONYPOM12A8C13B2D7', 'I Think My Wife Is Running Around On Me (Taco Hell)', 'ARDNS031187B9924F0', 2005, 186),
#  ('SOGOSOV12AF72A285E', '¿Dónde va Chichi?', 'ARGUVEV1187B98BA17', 1997, 313),
#  ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, 270),
#  ('SOLLHMX12AB01846DC', 'The Emperor Falls', 'AR1Y2PT1187FB5B9CE', 0, 485),
#  ('SOBZBAZ12A6D4F8742', 'Spanish Grease', 'AROUOZZ1187B9ABE51', 1997, 168),
#  ('SOMUYGI12AB0188633', 'La Culpa', 'ARL7K851187B99ACD2', 0, 226),
#  ('SOZVMJI12AB01808AF', 'Synthetic Dream', 'ARNPAGP1241B9C7FD4', 0, 166),
#  ('SOWTBJW12AC468AC6E', 'Broken-Down Merry-Go-Round', 'ARQGYP71187FB44566', 0, 152),
#  ('SOUQQEA12A8C134B1B', 'High Tide', 'ARIG6O41187B988BDD', 0, 229),
#  ('SORAMLE12AB017C8B0', 'Auguri Cha Cha', 'ARHHO3O1187B989413', 0, 192),
#  ('SOKEJEJ12A8C13E0D0', 'The Urgency (LP Version)', 'ARC43071187B990240', 0, 245),
#  ('SOBEBDG12A58A76D60', 'Kassie Jones', 'ARI3BMM1187FB4255E', 0, 221),
#  ('SOBONFF12A6D4F84D8', 'Tonight Will Be Alright', 'ARIK43K1187B9AE54C', 1986, 307),
#  ('SOHUOAP12A8AE488E9', 'Floating', 'ARD842G1187B997376', 1987, 491),
#  ('SOILPQQ12AB017E82A', 'Sohna Nee Sohna Data', 'AR1ZHYZ1187FB3C717', 0, 599),
#  ('SOXLBJT12A8C140925', 'Caught In A Dream', 'ARYKCQI1187FB3B18F', 2004, 290),
#  ('SOTTDKS12AB018D69B', 'It Wont Be Christmas', 'ARMBR4Y1187B9990EB', 0, 241),
#  ('SOZHPGD12A8C1394FE', 'Baby Come To Me', 'AR9AWNF1187B9AB0B4', 0, 237),
#  ('SOMVWWT12A58A7AE05', 'Knocked Out Of The Park', 'ARQ9BO41187FB5CF1F', 0, 183),
#  ('SOPVXLX12A8C1402D5', 'Larger Than Life', 'AR3JMC51187B9AE49D', 1999, 236),
#  ('SOBBXLX12A58A79DDA', 'Erica (2005 Digital Remaster)', 'AREDBBQ1187B98AFF5', 0, 139),
#  ('SOAOIBZ12AB01815BE', 'I Hold Your Hand In Mine [Live At Royal Albert Hall]', 'ARPBNLO1187FB3D52F', 2000, 43),
#  ('SOQVMXR12A81C21483', 'Salt In NYC', 'ARKULSX1187FB45F84', 0, 424),
#  ('SOSLAVG12A8C13397F', 'Den Pai Alo', 'AROGWRA122988FEE45', 0, 244),
#  ('SODUJBS12A8C132150', 'Wessex Loses a Bride', 'ARI2JSK1187FB496EF', 0, 112),
#  ('SOQLGFP12A58A7800E', 'OAKtown', 'ARD7TVE1187B99BFB1', 0, 259),
#  ('SOTUKVB12AB0181477', 'Blessed Assurance', 'AR7ZKHQ1187B98DD73', 1993, 271),
#  ('SODREIN12A58A7F2E5', 'A Whiter Shade Of Pale (Live @ Fillmore West)', 'ARLTWXK1187FB5A3F8', 0, 326),
#  ('SOSWKAV12AB018FC91', 'Midnight Star', 'ARULZCI1241B9C8611', 0, 336),
#  ('SOWQTQZ12A58A7B63E', 'Streets On Fire (Explicit Album Version)', 'ARPFHN61187FB575F6', 0, 280),
#  ('SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff', 'ARJIE2Y1187B994AB7', 0, 153),
#  ('SONSKXP12A8C13A2C9', 'Native Soul', 'AR0IAWL1187B9A96D0', 2003, 197),
#  ('SORRZGD12A6310DBC3', 'Harajuku Girls', 'ARVBRGZ1187FB4675A', 2004, 291),
#  ('SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 150),
#  ('SODAUVL12A8C13D184', 'Prognosis', 'ARWB3G61187FB49404', 2000, 364),
#  ('SOLYIBD12A8C135045', 'Music is what we love', 'AR051KA1187B98B2FF', 0, 262),
#  ('SOFCHDR12AB01866EF', 'Living Hell', 'AREVWGE1187B9B890A', 0, 282),
#  ('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 'ARNF6401187FB57032', 1994, 305),
#  ('SOGDBUF12A8C140FAA', 'Intro', 'AR558FS1187FB45658', 2003, 76),
#  ('SOBKWDJ12A8C13B2F3', 'Wild Rose (Back 2 Basics Mix)', 'AR36F9J1187FB406F1', 0, 231),
#  ('SOBCOSW12A8C13D398', 'Rumba De Barcelona', 'AR7SMBG1187B9B9066', 0, 218),
#  ('SOBAYLL12A8C138AF9', 'Sono andati? Fingevo di dormire', 'ARDR4AC1187FB371A1', 0, 511),
#  ('SOOJPRH12A8C141995', 'Loaded Like A Gun', 'ARBGXIG122988F409D', 0, 173),
#  ('SOPEGZN12AB0181B3D', 'Get Your Head Stuck On Your Neck', 'AREDL271187FB40F44', 0, 46),
#  ('SOXILUQ12A58A7C72A', 'Jenny Take a Ride', 'ARP6N5A1187B99D1A3', 2004, 207),
#  ('SOTCKKY12AB018A141', 'Sonnerie lalaleulé hi houuu', 'ARGSAFR1269FB35070', 0, 30),
#  ('SOLEYHO12AB0188A85', 'Got My Mojo Workin', 'ARAGB2O1187FB3A161', 0, 338),
#  ('SOGVQGJ12AB017F169', 'Ten Tonne', 'AR62SOJ1187FB47BB5', 2005, 338),
#  ('SOFFKZS12AB017F194', 'A Higher Place (Album Version)', 'ARBEBBY1187B9B43DB', 1994, 236),
#  ('SOFNOQK12AB01840FC', 'Kutt Free (DJ Volume Remix)', 'ARNNKDK1187B98BBD5', 0, 407),
#  ('SOQOTLQ12AB01868D0', 'Clementina Santafè', 'ARGCY1Y1187B9A4FA5', 0, 153)]

# %%
# %sql SELECT * FROM user LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('student',)]

# %%
# %sql SELECT * FROM users limit 10
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [(69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (92, 'Ryann', 'Smith', 'F', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free'),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'free'),
#  (96, 'Cierra', 'Finley', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (44, 'Aleena', 'Kirby', 'F', 'paid'),
#  (67, 'Colm', 'Santana', 'M', 'free')]

# %%
# %sql SELECT count(*) from songplays where song_id is null
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(6820,)]

# %%
# %sql SELECT count(*) FROM songplays
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(6820,)]

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (92, 'Ryann', 'Smith', 'F', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free')]

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (92, 'Ryann', 'Smith', 'F', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free')]

# %%
# %sql SELECT count(*) FROM users
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(96,)]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 270),
#  ('SOFSOCN12A8C143F5D', 'Face the Ashes', 'ARXR32B1187FB57099', 2007, 210),
#  ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, 190),
#  ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, 219)]

# %%
# %sql SELECT count(*) FROM songs
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(71,)]

# %%
# %sql SELECT * FROM songs JOIN artists using(artist_id)
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('AR7G5I41187FB4CE6C', 'SONHOTT12A8C13493C', 'Something Girls', 1982, 233, 'Adam Ant', 'London, England', nan, nan),
#  ('AR8ZCNI1187B9A069B', 'SOIAZJW12AB01853F1', 'Pink World', 1984, 270, 'Planet P Project', '', nan, nan),
#  ('ARXR32B1187FB57099', 'SOFSOCN12A8C143F5D', 'Face the Ashes', 2007, 210, 'Gob', '', nan, nan),
#  ('AR10USD1187B99F3F1', 'SOHKNRJ12A6701D1F8', 'Drop of Rain', 0, 190, 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', nan, nan),
#  ('ARGSJW91187B9B1D6B', 'SOQHXMF12AB0182363', 'Young Boy Blues', 0, 219, 'JennyAnyKind', 'North Carolina', 35.21962, -80.01955),
#  ('ARMJAGH1187FB546F3', 'SOCIWDW12A8C13D406', 'Soul Deep', 1969, 148, 'The Box Tops', 'Memphis, TN', 35.14968, -90.04892),
#  ('ARD7TVE1187B99BFB1', 'SOMZWCG12A8C13C480', "I Didn't Mean To", 0, 219, 'Casual', 'California - LA', nan, nan),
#  ('ARKRRTF1187B9984DA', 'SOXVLOJ12AB0189215', 'Amor De Cabaret', 0, 177, 'Sonora Santanera', '', nan, nan),
#  ('ARNTLGG11E2835DDB9', 'SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 0, 266, 'Clp', '', nan, nan),
#  ('ARKFYS91187B98E58F', 'SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 0, 268, 'Jeff And Sheri Easter', '', nan, nan),
#  ('ARD0S291187B9B7BF5', 'SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 0, 115, 'Rated R', 'Ohio', nan, nan),
#  ('ARH4Z031187B9A71F2', 'SOVYKGO12AB0187199', 'Crazy Mixed Up World', 1961, 156, 'Faye Adams', 'Newark, NJ', 40.73197, -74.17418),
#  ('ARB29H41187B98F0EF', 'SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 1972, 343, 'Terry Callier', 'Chicago', 41.88415, -87.63241),
#  ('AR0RCMP1187FB3F427', 'SOGXHEG12AB018653E', 'It Makes No Difference Now', 1992, 133, 'Billie Jo Spears', 'Beaumont, TX', 30.08615, -94.10158),
#  ('AR47JEX1187B995D81', 'SOBLGCN12AB0183212', 'James (Hold The Ladder Steady)', 1985, 125, 'SUE THOMPSON', 'Nevada, MO', 37.83721, -94.35868),
#  ('ARNTLGG11E2835DDB9', 'SOZQDIU12A58A7BCF6', 'Superconfidential', 0, 338, 'Clp', '', nan, nan),
#  ('AREBBGV1187FB523D2', 'SOOLYAZ12A6701F4A6', 'Laws Patrolling (Album Version)', 0, 174, "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 'Houston, TX', nan, nan),
#  ('ARMAC4T1187FB3FA4C', 'SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 2004, 208, 'The Dillinger Escape Plan', 'Morris Plains, NJ', 40.82624, -74.47995),
#  ('ARAJPHH1187FB5566A', 'SOYTPEP12AB0180E7B', 'Twist and Shout', 1964, 165, 'The Shangri-Las', 'Queens, NY', 40.7038, -73.83168),
#  ('ARGIWFO1187B9B55B7', 'SOPSWQW12A6D4F8781', 'Made Like This (Live)', 0, 225, 'Five Bolt Main', '', nan, nan),
#  ('ARDNS031187B9924F0', 'SONYPOM12A8C13B2D7', 'I Think My Wife Is Running Around On Me (Taco Hell)', 2005, 186, 'Tim Wilson', 'Georgia', 32.67828, -83.22295),
#  ('ARGUVEV1187B98BA17', 'SOGOSOV12AF72A285E', '¿Dónde va Chichi?', 1997, 313, 'Sierra Maestra', '', nan, nan),
#  ('AR5KOSW1187FB35FF4', 'SOZCTXZ12AB0182364', 'Setanta matins', 0, 270, 'Elena', 'Dubai UAE', 49.80388, 15.47491),
#  ('AR1Y2PT1187FB5B9CE', 'SOLLHMX12AB01846DC', 'The Emperor Falls', 0, 485, 'John Wesley', 'Brandon', 27.94017, -82.32547),
#  ('AROUOZZ1187B9ABE51', 'SOBZBAZ12A6D4F8742', 'Spanish Grease', 1997, 168, 'Willie Bobo', 'New York, NY [Spanish Harlem]', 40.79195, -73.94512),
#  ('ARL7K851187B99ACD2', 'SOMUYGI12AB0188633', 'La Culpa', 0, 226, 'Andy Andy', '', nan, nan),
#  ('ARNPAGP1241B9C7FD4', 'SOZVMJI12AB01808AF', 'Synthetic Dream', 0, 166, 'lextrical', '', nan, nan),
#  ('ARQGYP71187FB44566', 'SOWTBJW12AC468AC6E', 'Broken-Down Merry-Go-Round', 0, 152, 'Jimmy Wakely', 'Mineola, AR', 34.31109, -94.02978),
#  ('ARIG6O41187B988BDD', 'SOUQQEA12A8C134B1B', 'High Tide', 0, 229, 'Richard Souther', 'United States', 37.16793, -95.84502),
#  ('ARHHO3O1187B989413', 'SORAMLE12AB017C8B0', 'Auguri Cha Cha', 0, 192, 'Bob Azzam', '', nan, nan),
#  ('ARC43071187B990240', 'SOKEJEJ12A8C13E0D0', 'The Urgency (LP Version)', 0, 245, 'Wayne Watson', 'Wisner, LA', nan, nan),
#  ('ARI3BMM1187FB4255E', 'SOBEBDG12A58A76D60', 'Kassie Jones', 0, 221, 'Alice Stuart', 'Washington', 38.8991, -77.029),
#  ('ARIK43K1187B9AE54C', 'SOBONFF12A6D4F84D8', 'Tonight Will Be Alright', 1986, 307, 'Lionel Richie', 'Beverly Hills, CA', nan, nan),
#  ('ARD842G1187B997376', 'SOHUOAP12A8AE488E9', 'Floating', 1987, 491, 'Blue Rodeo', 'Toronto, Ontario, Canada', 43.64856, -79.38533),
#  ('AR1ZHYZ1187FB3C717', 'SOILPQQ12AB017E82A', 'Sohna Nee Sohna Data', 0, 599, 'Faiz Ali Faiz', '', nan, nan),
#  ('ARYKCQI1187FB3B18F', 'SOXLBJT12A8C140925', 'Caught In A Dream', 2004, 290, 'Tesla', '', nan, nan),
#  ('ARMBR4Y1187B9990EB', 'SOTTDKS12AB018D69B', 'It Wont Be Christmas', 0, 241, 'David Martin', 'California - SF', 37.77916, -122.42005),
#  ('AR9AWNF1187B9AB0B4', 'SOZHPGD12A8C1394FE', 'Baby Come To Me', 0, 237, 'Kenny G featuring Daryl Hall', 'Seattle, Washington USA', nan, nan),
#  ('ARQ9BO41187FB5CF1F', 'SOMVWWT12A58A7AE05', 'Knocked Out Of The Park', 0, 183, 'John Davis', 'Pennsylvania', 40.99471, -77.60454),
#  ('AR3JMC51187B9AE49D', 'SOPVXLX12A8C1402D5', 'Larger Than Life', 1999, 236, 'Backstreet Boys', 'Orlando, FL', 28.53823, -81.37739),
#  ('AREDBBQ1187B98AFF5', 'SOBBXLX12A58A79DDA', 'Erica (2005 Digital Remaster)', 0, 139, 'Eddie Calvert', '', nan, nan),
#  ('ARPBNLO1187FB3D52F', 'SOAOIBZ12AB01815BE', 'I Hold Your Hand In Mine [Live At Royal Albert Hall]', 2000, 43, 'Tiny Tim', 'New York, NY', 40.71455, -74.00712),
#  ('ARKULSX1187FB45F84', 'SOQVMXR12A81C21483', 'Salt In NYC', 0, 424, 'Trafik', 'Utah', 39.49974, -111.54732),
#  ('AROGWRA122988FEE45', 'SOSLAVG12A8C13397F', 'Den Pai Alo', 0, 244, 'Christos Dantis', '', nan, nan),
#  ('ARI2JSK1187FB496EF', 'SODUJBS12A8C132150', 'Wessex Loses a Bride', 0, 112, 'Nick Ingman;Gavyn Wright', 'London, England', 51.50632, -0.12714),
#  ('ARD7TVE1187B99BFB1', 'SOQLGFP12A58A7800E', 'OAKtown', 0, 259, 'Casual', 'California - LA', nan, nan),
#  ('AR7ZKHQ1187B98DD73', 'SOTUKVB12AB0181477', 'Blessed Assurance', 1993, 271, 'Glad', '', nan, nan),
#  ('ARLTWXK1187FB5A3F8', 'SODREIN12A58A7F2E5', 'A Whiter Shade Of Pale (Live @ Fillmore West)', 0, 326, 'King Curtis', 'Fort Worth, TX', 32.74863, -97.32925),
#  ('ARULZCI1241B9C8611', 'SOSWKAV12AB018FC91', 'Midnight Star', 0, 336, 'Luna Orbit Project', '', nan, nan),
#  ('ARPFHN61187FB575F6', 'SOWQTQZ12A58A7B63E', 'Streets On Fire (Explicit Album Version)', 0, 280, 'Lupe Fiasco', 'Chicago, IL', 41.88415, -87.63241),
#  ('ARJIE2Y1187B994AB7', 'SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff', 0, 153, 'Line Renaud', '', nan, nan),
#  ('AR0IAWL1187B9A96D0', 'SONSKXP12A8C13A2C9', 'Native Soul', 2003, 197, 'Danilo Perez', 'Panama', 8.4177, -80.11278),
#  ('ARVBRGZ1187FB4675A', 'SORRZGD12A6310DBC3', 'Harajuku Girls', 2004, 291, 'Gwen Stefani', '', nan, nan),
#  ('AR8IEZO1187B99055E', 'SOINLJW12A8C13314C', 'City Slickers', 2008, 150, 'Marc Shaiman', '', nan, nan),
#  ('ARWB3G61187FB49404', 'SODAUVL12A8C13D184', 'Prognosis', 2000, 364, 'Steve Morse', 'Hamilton, Ohio', nan, nan),
#  ('AR051KA1187B98B2FF', 'SOLYIBD12A8C135045', 'Music is what we love', 0, 262, 'Wilks', '', nan, nan),
#  ('AREVWGE1187B9B890A', 'SOFCHDR12AB01866EF', 'Living Hell', 0, 282, 'Bitter End', 'Noci (BA)', -13.442, -41.9952),
#  ('ARNF6401187FB57032', 'SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 1994, 305, 'Sophie B. Hawkins', 'New York, NY [Manhattan]', 40.79086, -73.96644),
#  ('AR558FS1187FB45658', 'SOGDBUF12A8C140FAA', 'Intro', 2003, 76, '40 Grit', '', nan, nan),
#  ('AR36F9J1187FB406F1', 'SOBKWDJ12A8C13B2F3', 'Wild Rose (Back 2 Basics Mix)', 0, 231, 'Bombay Rockers', 'Denmark', 56.27609, 9.51695),
#  ('AR7SMBG1187B9B9066', 'SOBCOSW12A8C13D398', 'Rumba De Barcelona', 0, 218, 'Los Manolos', '', nan, nan),
#  ('ARDR4AC1187FB371A1', 'SOBAYLL12A8C138AF9', 'Sono andati? Fingevo di dormire', 0, 511, 'Montserrat Caballé;Placido Domingo;Vicente Sardinero;Judith Blegen;Sherrill Milnes;Georg Solti', '', nan, nan),
#  ('ARBGXIG122988F409D', 'SOOJPRH12A8C141995', 'Loaded Like A Gun', 0, 173, 'Steel Rain', 'California - SF', 37.77916, -122.42005),
#  ('AREDL271187FB40F44', 'SOPEGZN12AB0181B3D', 'Get Your Head Stuck On Your Neck', 0, 46, 'Soul Mekanik', '', nan, nan),
#  ('ARP6N5A1187B99D1A3', 'SOXILUQ12A58A7C72A', 'Jenny Take a Ride', 2004, 207, 'Mitch Ryder', 'Hamtramck, MI', nan, nan),
#  ('ARGSAFR1269FB35070', 'SOTCKKY12AB018A141', 'Sonnerie lalaleulé hi houuu', 0, 30, 'Blingtones', '', nan, nan),
#  ('ARAGB2O1187FB3A161', 'SOLEYHO12AB0188A85', 'Got My Mojo Workin', 0, 338, 'Pucho & His Latin Soul Brothers', '', nan, nan),
#  ('AR62SOJ1187FB47BB5', 'SOGVQGJ12AB017F169', 'Ten Tonne', 2005, 338, 'Chase & Status', '', nan, nan),
#  ('ARBEBBY1187B9B43DB', 'SOFFKZS12AB017F194', 'A Higher Place (Album Version)', 1994, 236, 'Tom Petty', 'Gainesville, FL', nan, nan),
#  ('ARNNKDK1187B98BBD5', 'SOFNOQK12AB01840FC', 'Kutt Free (DJ Volume Remix)', 0, 407, 'Jinx', 'Zagreb Croatia', 45.80726, 15.967600000000001),
#  ('ARGCY1Y1187B9A4FA5', 'SOQOTLQ12AB01868D0', 'Clementina Santafè', 0, 153, 'Gloriana', 'Nashville, TN.', 36.16778, -86.77836)]

# %%
# %sql select * from songs
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 270),
#  ('SOFSOCN12A8C143F5D', 'Face the Ashes', 'ARXR32B1187FB57099', 2007, 210),
#  ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, 190),
#  ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, 219),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, 148),
#  ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 219),
#  ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', 0, 177),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', 0, 268),
#  ('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, 115),
#  ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, 156),
#  ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 'ARB29H41187B98F0EF', 1972, 343),
#  ('SOGXHEG12AB018653E', 'It Makes No Difference Now', 'AR0RCMP1187FB3F427', 1992, 133),
#  ('SOBLGCN12AB0183212', 'James (Hold The Ladder Steady)', 'AR47JEX1187B995D81', 1985, 125),
#  ('SOZQDIU12A58A7BCF6', 'Superconfidential', 'ARNTLGG11E2835DDB9', 0, 338),
#  ('SOOLYAZ12A6701F4A6', 'Laws Patrolling (Album Version)', 'AREBBGV1187FB523D2', 0, 174),
#  ('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, 208),
#  ('SOYTPEP12AB0180E7B', 'Twist and Shout', 'ARAJPHH1187FB5566A', 1964, 165),
#  ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 'ARGIWFO1187B9B55B7', 0, 225),
#  ('SONYPOM12A8C13B2D7', 'I Think My Wife Is Running Around On Me (Taco Hell)', 'ARDNS031187B9924F0', 2005, 186),
#  ('SOGOSOV12AF72A285E', '¿Dónde va Chichi?', 'ARGUVEV1187B98BA17', 1997, 313),
#  ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, 270),
#  ('SOLLHMX12AB01846DC', 'The Emperor Falls', 'AR1Y2PT1187FB5B9CE', 0, 485),
#  ('SOBZBAZ12A6D4F8742', 'Spanish Grease', 'AROUOZZ1187B9ABE51', 1997, 168),
#  ('SOMUYGI12AB0188633', 'La Culpa', 'ARL7K851187B99ACD2', 0, 226),
#  ('SOZVMJI12AB01808AF', 'Synthetic Dream', 'ARNPAGP1241B9C7FD4', 0, 166),
#  ('SOWTBJW12AC468AC6E', 'Broken-Down Merry-Go-Round', 'ARQGYP71187FB44566', 0, 152),
#  ('SOUQQEA12A8C134B1B', 'High Tide', 'ARIG6O41187B988BDD', 0, 229),
#  ('SORAMLE12AB017C8B0', 'Auguri Cha Cha', 'ARHHO3O1187B989413', 0, 192),
#  ('SOKEJEJ12A8C13E0D0', 'The Urgency (LP Version)', 'ARC43071187B990240', 0, 245),
#  ('SOBEBDG12A58A76D60', 'Kassie Jones', 'ARI3BMM1187FB4255E', 0, 221),
#  ('SOBONFF12A6D4F84D8', 'Tonight Will Be Alright', 'ARIK43K1187B9AE54C', 1986, 307),
#  ('SOHUOAP12A8AE488E9', 'Floating', 'ARD842G1187B997376', 1987, 491),
#  ('SOILPQQ12AB017E82A', 'Sohna Nee Sohna Data', 'AR1ZHYZ1187FB3C717', 0, 599),
#  ('SOXLBJT12A8C140925', 'Caught In A Dream', 'ARYKCQI1187FB3B18F', 2004, 290),
#  ('SOTTDKS12AB018D69B', 'It Wont Be Christmas', 'ARMBR4Y1187B9990EB', 0, 241),
#  ('SOZHPGD12A8C1394FE', 'Baby Come To Me', 'AR9AWNF1187B9AB0B4', 0, 237),
#  ('SOMVWWT12A58A7AE05', 'Knocked Out Of The Park', 'ARQ9BO41187FB5CF1F', 0, 183),
#  ('SOPVXLX12A8C1402D5', 'Larger Than Life', 'AR3JMC51187B9AE49D', 1999, 236),
#  ('SOBBXLX12A58A79DDA', 'Erica (2005 Digital Remaster)', 'AREDBBQ1187B98AFF5', 0, 139),
#  ('SOAOIBZ12AB01815BE', 'I Hold Your Hand In Mine [Live At Royal Albert Hall]', 'ARPBNLO1187FB3D52F', 2000, 43),
#  ('SOQVMXR12A81C21483', 'Salt In NYC', 'ARKULSX1187FB45F84', 0, 424),
#  ('SOSLAVG12A8C13397F', 'Den Pai Alo', 'AROGWRA122988FEE45', 0, 244),
#  ('SODUJBS12A8C132150', 'Wessex Loses a Bride', 'ARI2JSK1187FB496EF', 0, 112),
#  ('SOQLGFP12A58A7800E', 'OAKtown', 'ARD7TVE1187B99BFB1', 0, 259),
#  ('SOTUKVB12AB0181477', 'Blessed Assurance', 'AR7ZKHQ1187B98DD73', 1993, 271),
#  ('SODREIN12A58A7F2E5', 'A Whiter Shade Of Pale (Live @ Fillmore West)', 'ARLTWXK1187FB5A3F8', 0, 326),
#  ('SOSWKAV12AB018FC91', 'Midnight Star', 'ARULZCI1241B9C8611', 0, 336),
#  ('SOWQTQZ12A58A7B63E', 'Streets On Fire (Explicit Album Version)', 'ARPFHN61187FB575F6', 0, 280),
#  ('SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff', 'ARJIE2Y1187B994AB7', 0, 153),
#  ('SONSKXP12A8C13A2C9', 'Native Soul', 'AR0IAWL1187B9A96D0', 2003, 197),
#  ('SORRZGD12A6310DBC3', 'Harajuku Girls', 'ARVBRGZ1187FB4675A', 2004, 291),
#  ('SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 150),
#  ('SODAUVL12A8C13D184', 'Prognosis', 'ARWB3G61187FB49404', 2000, 364),
#  ('SOLYIBD12A8C135045', 'Music is what we love', 'AR051KA1187B98B2FF', 0, 262),
#  ('SOFCHDR12AB01866EF', 'Living Hell', 'AREVWGE1187B9B890A', 0, 282),
#  ('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 'ARNF6401187FB57032', 1994, 305),
#  ('SOGDBUF12A8C140FAA', 'Intro', 'AR558FS1187FB45658', 2003, 76),
#  ('SOBKWDJ12A8C13B2F3', 'Wild Rose (Back 2 Basics Mix)', 'AR36F9J1187FB406F1', 0, 231),
#  ('SOBCOSW12A8C13D398', 'Rumba De Barcelona', 'AR7SMBG1187B9B9066', 0, 218),
#  ('SOBAYLL12A8C138AF9', 'Sono andati? Fingevo di dormire', 'ARDR4AC1187FB371A1', 0, 511),
#  ('SOOJPRH12A8C141995', 'Loaded Like A Gun', 'ARBGXIG122988F409D', 0, 173),
#  ('SOPEGZN12AB0181B3D', 'Get Your Head Stuck On Your Neck', 'AREDL271187FB40F44', 0, 46),
#  ('SOXILUQ12A58A7C72A', 'Jenny Take a Ride', 'ARP6N5A1187B99D1A3', 2004, 207),
#  ('SOTCKKY12AB018A141', 'Sonnerie lalaleulé hi houuu', 'ARGSAFR1269FB35070', 0, 30),
#  ('SOLEYHO12AB0188A85', 'Got My Mojo Workin', 'ARAGB2O1187FB3A161', 0, 338),
#  ('SOGVQGJ12AB017F169', 'Ten Tonne', 'AR62SOJ1187FB47BB5', 2005, 338),
#  ('SOFFKZS12AB017F194', 'A Higher Place (Album Version)', 'ARBEBBY1187B9B43DB', 1994, 236),
#  ('SOFNOQK12AB01840FC', 'Kutt Free (DJ Volume Remix)', 'ARNNKDK1187B98BBD5', 0, 407),
#  ('SOQOTLQ12AB01868D0', 'Clementina Santafè', 'ARGCY1Y1187B9A4FA5', 0, 153)]

# %%
# %sql SELECT song_id, artist_id FROM songs JOIN artists using(artist_id) WHERE title = 'Fuck Kitty'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', '', nan, nan),
#  ('ARXR32B1187FB57099', 'Gob', '', nan, nan),
#  ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', nan, nan),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.21962, -80.01955)]

# %%
# %sql SELECT count(*) FROM artists
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(69,)]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 11, 2, 33, 56, 796000), 2, 11, 45, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 11, 2, 36, 10, 796000), 2, 11, 45, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 11, 2, 40, 34, 796000), 2, 11, 45, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 11, 4, 36, 13, 796000), 4, 11, 45, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 11, 4, 36, 46, 796000), 4, 11, 45, 11, 2018, 0)]

# %%
# %sql SELECT count(*) FROM time
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(6813,)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %% [markdown]
# # Sanity Tests
#
# Execute the cells below once you are ready to submit the project. Some basic sanity testing will be performed to esnure that your work does NOT contain any commonly found issues.
#
# Run each cell and if a cell produces an warning message is orange, you should make appropriate changes to your code before submitting. If all test in a cell pass,no warnings will be printed.
#
# The test cases assume that you are using certain column names in your tables. If you get a `IndexError: single positional indexer is out-of-bounds` you may need to change the column names being used by the test cases. Instructions for doing this appear right boefore cell that may require these changes.
#
# The tests below are only meant to help you make your work foolproof. The submission will still be graded by a human grader against the project rubric.
#
# ---

# %% [markdown]
# ## Grab Table Names for Testing

# %%
import sql_queries as sqlq

# %%
# %%sql _tablenames <<
# SELECT tablename
# FROM pg_catalog.pg_tables
# WHERE schemaname != 'pg_catalog' AND schemaname != 'information_schema' AND tableowner = 'student';
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# Returning data to local variable _tablenames

# %%
tablenames = _tablenames.DataFrame()

# %%
user_table = [name for name in list(tablenames.tablename) if name in sqlq.user_table_create][0]
song_table = [name for name in list(tablenames.tablename) if name in sqlq.song_table_create][0]
artists_table = [name for name in list(tablenames.tablename) if name in sqlq.artist_table_create][0]
songplay_table = [name for name in list(tablenames.tablename) if name in sqlq.songplay_table_create][0]

# %% [markdown]
# ## Run Primary Key Tests

# %%
# %sql _output << SELECT a.attname, format_type(a.atttypid, a.atttypmod) AS data_type, a.attnotnull, i.indisprimary \
FROM   pg_index i \
JOIN   pg_attribute a ON a.attrelid = i.indrelid \
                     AND a.attnum = ANY(i.indkey) \
WHERE  i.indrelid = '{user_table}'::regclass
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# Returning data to local variable _output

# %%
if not _output:
    print('\033[93m'+'[WARNING] '+ f"The {user_table} table does not have a primary key!")

# %%
# %sql _output << SELECT a.attname, format_type(a.atttypid, a.atttypmod) AS data_type, a.attnotnull, i.indisprimary \
FROM   pg_index i \
JOIN   pg_attribute a ON a.attrelid = i.indrelid \
                     AND a.attnum = ANY(i.indkey) \
WHERE  i.indrelid = '{artists_table}'::regclass
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# Returning data to local variable _output

# %%
if not _output: 
    print('\033[93m'+'[WARNING] '+ f"The {artists_table} table does not have a primary key!")

# %%
# %sql _output << SELECT a.attname, format_type(a.atttypid, a.atttypmod) AS data_type, a.attnotnull, i.indisprimary \
FROM   pg_index i \
JOIN   pg_attribute a ON a.attrelid = i.indrelid \
                     AND a.attnum = ANY(i.indkey) \
WHERE  i.indrelid = '{songplay_table}'::regclass
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# Returning data to local variable _output

# %%
if not _output:
    print('\033[93m'+'[WARNING] '+ f"The {songplay_table} table does not have a primary key!")

# %%
# %sql _output << SELECT a.attname, format_type(a.atttypid, a.atttypmod) AS data_type, a.attnotnull, i.indisprimary \
FROM   pg_index i \
JOIN   pg_attribute a ON a.attrelid = i.indrelid \
                     AND a.attnum = ANY(i.indkey) \
WHERE  i.indrelid = '{song_table}'::regclass
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# Returning data to local variable _output

# %%
if not _output:
    print('\033[93m'+'[WARNING] '+ f"The {song_table} table does not have a primary key!")

# %% [markdown]
# ## Run Data Type and Constraints Check

# %%
# %sql _output << SELECT * FROM information_schema.columns where table_name='{user_table}'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# Returning data to local variable _output

# %% [markdown]
# **Check the column `user_id` for correct data type.**
# If you get a `IndexError: single positional indexer is out-of-bounds` error, you may be using a different column name. Change the column name below and run the cell again.

# %%
output = _output.DataFrame()
_dtype = output[output.column_name == 'user_id'].data_type.iloc[0]
if _dtype not in ['integer', 'bigint']:
    print('\033[93m'+'[WARNING] '+ f"Type {_dtype} may not be an appropriate data type for column 'user_id' in the '{user_table}' table.")

# %%
# %sql _output << SELECT * FROM information_schema.columns where table_name='{song_table}'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# Returning data to local variable _output

# %% [markdown]
# **Check the column `year` for correct data type.
# Check columns `title` and `duration` for not-NULL constraints.**
#
# If you get a `IndexError: single positional indexer is out-of-bounds` error, you may be using different column names. Change the column name(s) below and run the cell again.

# %%
output = _output.DataFrame()

_dtype = output[output.column_name == 'year'].data_type.iloc[0]
if _dtype not in ['integer']:
    print('\033[93m'+'[WARNING] '+ f"Type '{_dtype}' may not be an appropriate data type for column 'year' in the '{song_table}' table.")

_nullable_title = output[output.column_name == 'title'].is_nullable.iloc[0]
_nullable_duration = output[output.column_name == 'duration'].is_nullable.iloc[0]
if (_nullable_duration != 'NO') or (_nullable_title != 'NO'): 
    print('\033[93m'+'[WARNING] '+ f"You may want to add appropriate NOT NULL constraints to the '{song_table}' table.")

# %%
# %sql _output << SELECT * FROM information_schema.columns where table_name='{artists_table}'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# Returning data to local variable _output

# %% [markdown]
# **Check the columns `latitude` and `longitude` for correct data type.
# Check column `name` for not-NULL constraint.**
#
# If you get a `IndexError: single positional indexer is out-of-bounds` error, you may be using different column names. Change the column name(s) below and run the cell again.

# %%
output = _output.DataFrame()

_dtype_latitude = output[output.column_name == 'latitude'].data_type.iloc[0]
if _dtype_latitude not in ['double precision']:
    print('\033[93m'+'[WARNING] '+ f"Type '{_dtype_latitude}' may not be an appropriate data type for column 'latitude' in the '{artists_table}' table")

_dtype_longitude = output[output.column_name == 'longitude'].data_type.iloc[0]
if _dtype_longitude not in ['double precision']:
    print('\033[93m'+'[WARNING] '+ f"Type '{_dtype_longitude}' may not be an appropriate data type for column 'longitude' in the '{artists_table}' table")


_nullable_name = output[output.column_name == 'name'].is_nullable.iloc[0]
if _nullable_name != 'NO':
    print('\033[93m'+'[WARNING] '+ f"You may want to add appropriate NOT NULL constraints to the '{artists_table}' table.")

# %%
# %sql _output << SELECT * FROM information_schema.columns where table_name='{songplay_table}'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 9 rows affected.
# Returning data to local variable _output

# %% [markdown]
# **Check the columns `start_time` and `user_id` for correct data type.
# Check columns `start_time` and `user_id` for not-NULL constraint.**
#
# If you get a `IndexError: single positional indexer is out-of-bounds` error, you may be using different column names. Change the column name(s) below and run the cell again.

# %%
output = _output.DataFrame()

_dtype_start_time = output[output.column_name == 'start_time'].data_type.iloc[0]
if 'timestamp' not in _dtype_start_time: 
    print('\033[93m'+'[WARNING] '+ f"Type '{_dtype_start_time}' may not be an appropriate data type for column 'start_time' in the '{songplay_table}' table.")

_dtype_user_id = output[output.column_name == 'user_id'].data_type.iloc[0]
if _dtype_user_id not in ['integer', 'bigint']:
    print('\033[93m'+'[WARNING] '+ f"Type '{_dtype_user_id}' may not be an appropriate data type for column 'user_id' in the '{songplay_table}' table.")


_nullable_time = output[output.column_name == 'start_time'].is_nullable.iloc[0]
_nullable_uid = output[output.column_name == 'user_id'].is_nullable.iloc[0]

if (_nullable_time != 'NO') or (_nullable_uid != 'NO'):
    print('\033[93m'+'[WARNING] '+ f"You may want to add appropriate NOT NULL constraints to the '{songplay_table}' table.")

# %% [markdown]
# ## Run Tests for Upsertion Check

# %%
import re

# %%
if not re.search('ON\s+CONFLICT',sqlq.songplay_table_insert,re.IGNORECASE) or \
   not re.search('ON\s+CONFLICT',sqlq.user_table_insert,re.IGNORECASE) or \
   not re.search('ON\s+CONFLICT',sqlq.song_table_insert,re.IGNORECASE) or \
   not re.search('ON\s+CONFLICT',sqlq.artist_table_insert,re.IGNORECASE):
    print('\033[93m'+'[WARNING]Some of your insert queries may need an "ON CONFLICT" clause.')
    print('\033[93m'+'         You can either skip conflicting insertions with with "ON CONFLICT DO NOTHING"')
    print('\033[93m'+'         OR use "ON CONFLICT DO UPDATE SET"')
    print('\033[93m'+'         Check this link for more details: https://www.postgresqltutorial.com/postgresql-upsert/')
